# %%
from epd_plot_shift import *
from sunpy.coordinates import get_horizons_coord
# Import mymodule
import importlib.machinery
import importlib.util
loader = importlib.machinery.SourceFileLoader( 'savecsv', r'C:\Users\Omistaja\Documents\GitHub\SavingCsv\savecsv.py' )
spec = importlib.util.spec_from_loader( 'savecsv', loader )
mymodule = importlib.util.module_from_spec( spec )
loader.exec_module( mymodule )

# %%
pos = get_horizons_coord('Solar Orbiter', '2021-05-23', 'id')
dist = np.round(pos.radius.value, 2)
print('Distance' , dist)
spiral_len = len_of_spiral(400,dist)
print('Length of spiral (AU) : ', spiral_len)
traveltime_min = traveltime_los(spiral_len, 0.004, 2, dist)
traveltime_max = traveltime_los(spiral_len, 10, 2, dist)
print('STEP traveltime (min) : ', traveltime_min)
print('HET traveltime (max) : ', traveltime_max)
# Out:
# INFO: Obtained JPL HORIZONS location for Solar Orbiter (spacecraft) (-144 [sunpy.coordinates.ephemeris]
# Distance 0.95
# Length of spiral (AU) :  1.0883677277488593
# STEP traveltime (min) :  72.76511319265764
# HET traveltime (max) :  9.062393251377229
# WARNING: AstropyDeprecationWarning: ``id_type``s 'majorbody' and 'id' are deprecated and replaced with ``None``, which has the same functionality. [astroquery.jplhorizons.core]

# %%
# Path to the solo data files.
data_path = r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/data/'

# Path to where images and .csv -files will be saved.
#image_path =r'C:/Users/Omistaja/Desktop\SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/20201118-1415/5min/sun/'
#csv_path = r'C:/Users/Omistaja/Desktop\SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/20201118-1415/5min/sun/'
folder = '20210522-0434'
image_path =r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'
csv_path = r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'

# %%
# Start and end day. Format: yyyymmdd.
start_date = 20210523
end_date = 20210523

# plot start and end format 'YYYY-MM-DD-HHmm'
plot_start = '2021-05-23-0200'
plot_end = '2021-05-23-0700'

# Backgroud window:
# Default values: bg_start= None, bg_end = None, bg_distance_from_window = None, bg_period = None
# You can either specify a time period by using the same format as for plot_start and plot_end for bg_start and bg_end
# If you specify bg_start and bg_end set bg_distance_from_window and bg_period to None
# For a moving background window set bg_start and bg_end to None and specify bg_distance_from_window and bg_period
# bg_distance_from_window is the distance of the background window start time from the peak window
# the input for bg_distance_from_window is in minutes
# bg_period is the length of the bg in minutes
# by specifying bg_distance_from_window and bg_period the bg will follow the first slope of the peak window
bg_start = None #'2021-10-09-0400' 
bg_end = None #'2021-10-09-0500'
bg_distance_from_window = 60
bg_period = 40

# injection time Format: yyyymmdd.
t_inj = '2021-05-23-0429'

# For a fixed non sliding window input travel_distance = 0, 
# travel_distance_second_slope = None, fixed_window = period in minutes
# For a fixed sliding window input travel_distance = distance in AU,
# travel_distance_second_slope = None, fixed_window = period in minutes
# for two slopes input travel_distance = distance in AU, 
# travel_distance_second_slope = distance 2 in AU, fixed_window = None
travel_distance = dist
travel_distance_second_slope = None 
fixed_window = 40 #either input time period in minutes or None
frac_nan_threshold = 0.9  # exclude all spectrum values with fraction of non-nan data points in search period lower than this



# Averaging. 'mean' = rolling mean, 'none' = no averaging.
averaging_mode = 'mean'
averaging = 5

# %%
# Toggle individual instruments. For use if for example one instrument doesn't have data yet.
ept = True
het = True
step = True


# Toggles the step masking from Ninas function. No reason to be False.
step_masking = True

# %%
# Toggle saving of the images and .csv -files.
saving = False
autodownload_data = True
all_ok = True

direction = 'sun'
data_type = 'l2'

# %% [markdown]
# ## STEP

# %%
if(step):
    df_particles_step, energies_step = epd_load(sensor='step', viewing='sun', level='l2', startdate=start_date, enddate=end_date, path=data_path, autodownload=True)
    data_step = extract_step_data(df_particles_step, plot_start, plot_end, t_inj, bgstart = bg_start , bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument = 'step', data_type = 'l2', averaging_mode=averaging_mode, averaging=averaging, masking=step_masking)
    if saving: write_to_csv(data_step, path=csv_path)
    #for bg_b in [False, True]:
    bg_b = False
    plot_channels(data_step, bg_subtraction=bg_b, path=image_path, savefig=saving)
    bg_b = True
    plot_spectrum_peak(data_step, bg_subtraction=bg_b, path=image_path, savefig=saving)
# Out:
# DatetimeIndex(['2021-05-23 00:01:16.254000', '2021-05-23 00:01:26.254000',
#                '2021-05-23 00:01:36.254000', '2021-05-23 00:01:46.254000',
#                '2021-05-23 00:01:56.254000', '2021-05-23 00:02:06.254000',
#                '2021-05-23 00:02:16.254000', '2021-05-23 00:02:26.254000',
#                '2021-05-23 00:02:36.254000', '2021-05-23 00:02:46.254000',
#                ...
#                '2021-05-23 23:59:36.397000', '2021-05-23 23:59:46.397000',
#                '2021-05-23 23:59:56.397000', '2021-05-24 00:00:06.397000',
#                '2021-05-24 00:00:16.397000', '2021-05-24 00:00:26.397000',
#                '2021-05-24 00:00:36.397000', '2021-05-24 00:00:46.397000',
#                '2021-05-24 00:00:56.397000', '2021-05-24 00:01:06.397000'],
#               dtype='datetime64[ns]', length=8640, freq=None)
# C:\Users\Omistaja\Documents\GitHub\epd-load-n-plot\epd_plot_shift.py:230: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## EPT

# %%
if(ept):
    df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
    #for ion_b in [False, True]:
    ion_b = True    
    data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging=averaging, masking=step_masking, ion_conta_corr=ion_b)
    if saving: write_to_csv(data_ept, path=csv_path)
    #for bg_b in [False, True]:
    bg_b = False
    plot_channels(data_ept, bg_subtraction=bg_b, path=image_path, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
    bg_b = True
    plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
    plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path, savefig=saving, frac_nan_threshold=frac_nan_threshold)
# Out:
# C:\Users\Omistaja\Anaconda3\lib\site-packages\heliopy\data\util.py:849: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{df_key}_{i}'] = data
# C:\Users\Omistaja\Anaconda3\lib\site-packages\heliopy\data\util.py:844: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[df_key] = data
# ...

# %% [markdown]
# ## HET

# %%
if(het):
    df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
    data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging=averaging)
    if saving: write_to_csv(data_het, path=csv_path)
    #for bg_b in [False, True]:
    bg_b = False    
    plot_channels(data_het, bg_subtraction=bg_b, path=image_path, savefig=saving)
    bg_b = True
    plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path, savefig=saving)
# Out:
# C:\Users\Omistaja\Anaconda3\lib\site-packages\heliopy\data\util.py:849: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{df_key}_{i}'] = data
# C:\Users\Omistaja\Anaconda3\lib\site-packages\heliopy\data\util.py:844: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[df_key] = data
# ...

# %%
if all_ok:
    saving = True
    image_path =r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'
    csv_path = r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'

    avs = ['5min']
    averagings = [5]
    directions = [ 'asun', 'north', 'south']
   
    for av in range(len(averagings)):
        image_path_1 = image_path+avs[av]+'/'+direction+'/'
        csv_path_1 = csv_path+avs[av]+'/'+direction+'/'
        path = image_path_1+'plot_variables.csv'

        df_particles_step, energies_step = epd_load(sensor='step', viewing='sun', level='l2', startdate=start_date, enddate=end_date, path=data_path, autodownload=True)
        data_step = extract_step_data(df_particles_step, plot_start, plot_end, t_inj, bgstart = bg_start , bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument = 'step', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking)
        if saving: write_to_csv(data_step, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)


        df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        #for ion_b in [False, True]:
        ion_b = True    
        data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
        if saving: write_to_csv(data_ept, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
        bg_b = True
        plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
        plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


        df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
        if saving: write_to_csv(data_het, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False    
        plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        
        mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)

        for dire in directions:
            image_path_1 = image_path+avs[av]+'/'+dire+'/'
            csv_path_1 = csv_path+avs[av]+'/'+dire+'/'
            path = image_path_1+'plot_variables.csv'

            df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            #for ion_b in [False, True]:
            ion_b = True    
            data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
            if saving: write_to_csv(data_ept, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False
            plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
            bg_b = True
            plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
            plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


            df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
            if saving: write_to_csv(data_het, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False    
            plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            bg_b = True
            plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            
            mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)
# Out:
# DatetimeIndex(['2021-05-23 00:01:16.254000', '2021-05-23 00:01:26.254000',
#                '2021-05-23 00:01:36.254000', '2021-05-23 00:01:46.254000',
#                '2021-05-23 00:01:56.254000', '2021-05-23 00:02:06.254000',
#                '2021-05-23 00:02:16.254000', '2021-05-23 00:02:26.254000',
#                '2021-05-23 00:02:36.254000', '2021-05-23 00:02:46.254000',
#                ...
#                '2021-05-23 23:59:36.397000', '2021-05-23 23:59:46.397000',
#                '2021-05-23 23:59:56.397000', '2021-05-24 00:00:06.397000',
#                '2021-05-24 00:00:16.397000', '2021-05-24 00:00:26.397000',
#                '2021-05-24 00:00:36.397000', '2021-05-24 00:00:46.397000',
#                '2021-05-24 00:00:56.397000', '2021-05-24 00:01:06.397000'],
#               dtype='datetime64[ns]', length=8640, freq=None)
# C:\Users\Omistaja\Documents\GitHub\epd-load-n-plot\epd_plot_shift.py:230: SettingWithCopyWarning:
# ...

# %%
if all_ok:
    saving = True
    image_path =r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'
    csv_path = r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'

    avs = [ '2min']
    averagings = [ 2]
    directions = [ 'asun', 'north', 'south']
   
    for av in range(len(averagings)):
        image_path_1 = image_path+avs[av]+'/'+direction+'/'
        csv_path_1 = csv_path+avs[av]+'/'+direction+'/'
        path = image_path_1+'plot_variables.csv'

        df_particles_step, energies_step = epd_load(sensor='step', viewing='sun', level='l2', startdate=start_date, enddate=end_date, path=data_path, autodownload=True)
        data_step = extract_step_data(df_particles_step, plot_start, plot_end, t_inj, bgstart = bg_start , bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument = 'step', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking)
        if saving: write_to_csv(data_step, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)


        df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        #for ion_b in [False, True]:
        ion_b = True    
        data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
        if saving: write_to_csv(data_ept, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
        bg_b = True
        plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
        plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


        df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
        if saving: write_to_csv(data_het, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False    
        plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        
        mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)

        for dire in directions:
            image_path_1 = image_path+avs[av]+'/'+dire+'/'
            csv_path_1 = csv_path+avs[av]+'/'+dire+'/'
            path = image_path_1+'plot_variables.csv'

            df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            #for ion_b in [False, True]:
            ion_b = True    
            data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
            if saving: write_to_csv(data_ept, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False
            plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
            bg_b = True
            plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
            plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


            df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
            if saving: write_to_csv(data_het, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False    
            plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            bg_b = True
            plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            
            mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)

# %%
if all_ok:
    saving = True
    image_path =r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'
    csv_path = r'C:/Users/Omistaja/Desktop/SRL/2021SRL/epd_plot-main/solo_loader-main-shift/events/'+folder+'/'

    avs = ['1min']
    averagings = [ 1]
    directions = [ 'asun', 'north', 'south']
   
    for av in range(len(averagings)):
        image_path_1 = image_path+avs[av]+'/'+direction+'/'
        csv_path_1 = csv_path+avs[av]+'/'+direction+'/'
        path = image_path_1+'plot_variables.csv'

        df_particles_step, energies_step = epd_load(sensor='step', viewing='sun', level='l2', startdate=start_date, enddate=end_date, path=data_path, autodownload=True)
        data_step = extract_step_data(df_particles_step, plot_start, plot_end, t_inj, bgstart = bg_start , bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument = 'step', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking)
        if saving: write_to_csv(data_step, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_step, bg_subtraction=bg_b, path=image_path_1, savefig=saving)


        df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        #for ion_b in [False, True]:
        ion_b = True    
        data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
        if saving: write_to_csv(data_ept, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False
        plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
        bg_b = True
        plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
        plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


        df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = direction, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
        data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
        if saving: write_to_csv(data_het, path=csv_path_1)
        #for bg_b in [False, True]:
        bg_b = False    
        plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        bg_b = True
        plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
        
        mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)

        for dire in directions:
            image_path_1 = image_path+avs[av]+'/'+dire+'/'
            csv_path_1 = csv_path+avs[av]+'/'+dire+'/'
            path = image_path_1+'plot_variables.csv'

            df_protons_ept, df_electrons_ept, energies_ept = epd_load(sensor = 'ept', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            #for ion_b in [False, True]:
            ion_b = True    
            data_ept = extract_data(df_protons_ept, df_electrons_ept, plot_start, plot_end, t_inj, bgend = bg_end, bg_distance_from_window = bg_distance_from_window, bg_period = bg_period,  travel_distance = travel_distance, travel_distance_second_slope=travel_distance_second_slope, fixed_window=fixed_window, instrument = 'ept', data_type = 'l2', averaging_mode=averaging_mode, averaging= averagings[av], masking=step_masking, ion_conta_corr=ion_b)
            if saving: write_to_csv(data_ept, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False
            plot_channels(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold, rel_err_threshold=0.5)
            bg_b = True
            plot_spectrum_peak(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold) 
            plot_spectrum_average(data_ept, bg_subtraction=bg_b, path=image_path_1, savefig=saving, frac_nan_threshold=frac_nan_threshold)      


            df_protons_het, df_electrons_het, energies_het = epd_load(sensor = 'het', viewing = dire, level = 'l2', startdate = start_date, enddate = end_date, path=data_path, autodownload=True)
            data_het = extract_data(df_protons_het, df_electrons_het, plot_start, plot_end, t_inj, bgstart = bg_start, bgend = bg_end,  bg_distance_from_window = bg_distance_from_window,bg_period = bg_period, travel_distance = travel_distance, travel_distance_second_slope = travel_distance_second_slope, fixed_window = fixed_window, instrument='het', data_type='l2', averaging_mode=averaging_mode, averaging= averagings[av])
            if saving: write_to_csv(data_het, path=csv_path_1)
            #for bg_b in [False, True]:
            bg_b = False    
            plot_channels(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            bg_b = True
            plot_spectrum_peak(data_het, bg_subtraction=bg_b, path=image_path_1, savefig=saving)
            
            mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)

# %%
path = image_path+'plot_variables.csv'
if saving:
    mymodule.save_info_plot(path, plot_start, plot_end, t_inj, bg_start , bg_end, bg_distance_from_window , bg_period, travel_distance, travel_distance_second_slope, fixed_window, data_type, averaging_mode, averaging, step_masking, ion_b, dist, spiral_len, traveltime_min, traveltime_max)
